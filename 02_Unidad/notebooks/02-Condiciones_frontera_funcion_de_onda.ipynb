# %% [markdown]
# # Unidad 02:  Mecánica Cuantica
# ## Tarea:  Condiciones de frontera para la función de onda
#
# - **Nombre:** Jesús Capistrán-Martínez
# - **email:** capistran@gmail.com
# - **Fecha:** Feb 09, 2023
#
# <a target="_blank" href="https://colab.research.google.com/github/jesuscapistran/fisica_electronica_2023/blob/main/02_Unidad/notebooks/02-Condiciones_frontera_funcion_de_onda.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# Objetivo: Modificar el código para graficar $\psi_n(x)$ y $|\psi_n(x)|^2$ (Pagina 1273)
#
#
# Primeros tres estados permitidos para una partícula confinada a una caja de una dimensión. Los estados se muestran sobrepuestos en la función de energía potencial de la figura. Las funciones de onda y las densidades de probabilidad se grafican verticalmente desde ejes separados que están corridos verticalmente para mayor claridad. Las posiciones de estos ejes sobre la función de energía potencial sugieren las energías relativas de los estados.
#
#
# ![jesuscapistran%202023-02-09%20at%2012.28.50%20PM.png](attachment:jesuscapistran%202023-02-09%20at%2012.28.50%20PM.png)

# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Código de ejemplo (Modificar más adelante para obtener psi(x) y np.abs(psi(x))^2)

# Generate x values
x = np.linspace(0, np.pi, 1000)

# Compute sin(x), cos(x), and sin(x^2)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x**2)


# Create the figure and axes objects
fig, axs = plt.subplots(3, 2, figsize=(7,5), sharex=True)

# Plot sin(x) in the first subplot
axs[0, 0].plot(x, y1, 'r', label='sin(x)')
axs[0, 0].set_title('sin(x)')
axs[0, 0].legend()

# Plot cos(x) in the second subplot
axs[0, 1].plot(x, y1, 'r', label='sin(x)')
axs[0, 1].set_title('sin(x)')
axs[0, 1].legend()

# Plot sin(x^2) in the third subplot
axs[1, 0].plot(x, y2, 'b', label='cos(x)')
axs[1, 0].set_title('cos(x)')
axs[1, 0].legend()

# Duplicate the first three subplots
axs[1, 1].plot(x, y2, 'b', label='cos(x)')
axs[1, 1].set_title('cos(x)')
axs[1, 1].legend()

axs[2, 0].plot(x, y3, 'g', label='sin(x^2)')
axs[2, 0].set_title('sin(x^2)')
axs[2, 0].legend()

axs[2, 1].plot(x, y3, 'g', label='sin(x^2)')
axs[2, 1].set_title('sin(x^2)')
axs[2, 1].legend()

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Función de onda
#
# $$ \psi(x) = A \sin(\frac{2\pi x}{\lambda})$$
#
# a) **Condiciones de frontera para la Función de onda:**
#
# - $\psi(0) = 0 $
# - $\psi(L) = 0 $
#
# b) **Valores permitidos para n = 1,2,3 ...**
#
# $$\frac{2\pi L}{\lambda}= n\pi $$
#
# $$ \psi(x) = A \sin\left[\frac{2\pi x}{(2L)/n}\right] =   A \sin\left[\frac{n \pi x}{L}\right]$$

# %% [markdown]
# ## Normalizar la función de onda
#
# Objetivo: Obtener A (Amplitud)
#
#
# $$ \int_{-\infty}^{\infty}  \! |\psi(x)|^2 \, dx = 1  $$
#
# $$ \int_{-\infty}^{\infty}  \! \left|A \sin\left(\frac{n \pi x}{L}\right)\right|^2\, dx = 1  $$
#
# - $A =  \, ?$

# %%
# Constantes 

L = 0.2e-9 # [nm]
n1 = 1      # Numero cuantico 
n2 = 2      # Numero cuantico 
n3 = 3      # Numero cuantico

# %%
# Crear el espacio 0 a L 

x = np.linspace(0, L, 1000)

# %%
# Programas las tres funciones de onda 

psi_1 = n1
psi_2 = n2
psi_3 = n3

# %%
# Densidad de probabilidad

# %%
# Graficar las funciones de onda y densidad de probailidad
# Nota: Modifica el codigo de las graficas anteriores (3 filas  y 2 columnas)
# Trata de imitar la grafica del libro lo mejor posible.

# %% [markdown]
# ## Conclusiones  (Responde las siguientes preguntas)
#
# - ¿Cuales son las longitudes de onda permitidas para n = 1,2,3?
#
#
# - Explica con tus propias palabras, ¿Qué es la función de onda?
